# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown

# %% [markdown]
# Evoluciones de población y economía

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown

# %% [markdown]
# El propósito es de: viendo las evoluciones de la población de los distintos municipios de España, tomar decisiones de inversión.
# Se tratará de ver si las tendencias de evolución de la población de un municipio están relacionadas con su evolución económica y posibilidades de inversión.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Puede que tengas más de una, pero tu proyecto lo harás teniendo una hipótesis principal.

# %%
# Escribe tu hipótesis principal en Markdown

# %% [markdown]
# El crecimiento de población de un municipio supone una mejora de sus variables económicas

# %%
# Escribe más hipótesis si las hubiera en Markdown

# %% [markdown]
# * Análisis de la influencia del tamaño del municipio en su evolución demográfica
# * Evolución de la tasa de paro según su demografía
# * Explorar oportunidades de posibles inversiones en municipios con crecimiento analizando su estructura económica.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una breve descripción del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
# describe la fuente de tus datos e incluye los links en Markdown

# %% [markdown]
# Principalmente el INE:
#
# [Empresas por municipio y actividad principal](https://www.ine.es/jaxiT3/Tabla.htm?t=4721&L=0)
#
# [Cifras oficiales de población de los municipios españoles](https://www.ine.es/dynt3/inebase/es/index.htm?padre=525)
#
# Y el SEPE para las cifras de paro:
#
# [Paro registrado por municipios](https://www.sepe.es/HomeSepe/que-es-el-sepe/estadisticas/datos-estadisticos/municipios.html)

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
import pandas as pd
import numpy as np

# %%
# Datos de paro por municipio, agrupado por sexo, edad y sector económico (falta poner nombres a las columnas)
df = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS2023.xls', sheet_name=provincia).iloc[7:,:]
df
# Out:
#      Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 7        2001.0   ABENGIBRE         26          0         <5          7
# 8        2002.0      ALATOZ         39         <5         <5         10
# 9        2003.0    ALBACETE      11764        485       1641       2214
# 10       2004.0    ALBATANA         60         <5         <5         12
# 11       2005.0     ALBOREA         56          0         <5         19
# ..          ...         ...        ...        ...        ...        ...
# 296     50295.0  VISTABELLA         <5         <5
# 297     50296.0   ZAIDA, LA         16                    <5          6
# 298     50297.0    ZARAGOZA      33896       1348       4506       7271
# 299     50298.0       ZUERA        315         14         37         64
# 300         NaN    ZARAGOZA      46097       1879       5991       9696
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# ...

# %%
csv = pd.read_excel('empresas/empresas_municipios.xls').iloc[7:,:]
csv
# Out:
#                     Resultados municipales    Unnamed: 1 Unnamed: 2  \
# 7                              Total Nacional    3430663    3366570
# 8                              01 Araba/Álava      18771      18628
# 9                      01001 Alegría-Dulantzi        154        169
# 10                              01002 Amurrio        601        596
# 11                              01003 Aramaio         43         46
# ...                                       ...        ...        ...
# 8191              50903 Villamayor de Gállego        155        160
# 8192                                 51 Ceuta       3744       3749
# 8193                              51001 Ceuta       3744       3749
# 8194                               52 Melilla       4856       5024
# 8195                            52001 Melilla       4856       5024
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 7       3404428    3363197    3337646    3282346    3236582    3186878
# ...

# %%
csv = pd.read_csv('poblacion/albacete copy.csv', index_col = "Unnamed: 0", encoding="latin1")
csv
# Out:
#                                    2022     2021     2020     2019     2018  \
# 02 Albacete                     385.727  386.464  388.270  388.167  388.786
# 02001 Abengibre                 739.000  748.000  761.000  790.000  757.000
# 02002 Alatoz                    496.000  496.000  506.000  519.000  529.000
# 02003 Albacete                  172.357  172.722  174.336  173.329  173.050
# 02004 Albatana                  670.000  681.000  679.000  692.000  693.000
# ...                                 ...      ...      ...      ...      ...
# 02082 Villatoya                 106.000  108.000  109.000  109.000   95.000
# 02083 Villavaliente             202.000  214.000  220.000  224.000  226.000
# 02084 Villaverde de Guadalimar  321.000  333.000  325.000  338.000  340.000
# 02085 Viveros                   335.000  328.000  329.000  337.000  340.000
# 02086 Yeste                       2.495    2.567    2.614    2.657    2.674
#
# ...
