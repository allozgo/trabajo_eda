# %%
import pandas as pd
import numpy as np

# %%
paro = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS2023.xls', sheet_name="PARO ALBACETE").iloc[7:,1:3]
paro
# Out:
#                   Unnamed: 1 Unnamed: 2
# 7                  ABENGIBRE         26
# 8                     ALATOZ         39
# 9                   ALBACETE      11764
# 10                  ALBATANA         60
# 11                   ALBOREA         56
# ..                       ...        ...
# 90             VILLAVALIENTE         12
# 91  VILLAVERDE DE GUADALIMAR         41
# 92                   VIVEROS         17
# 93                     YESTE        270
# 94                  ALBACETE      28060
#
# [88 rows x 2 columns]

# %%
provincias = ['PARO A CORUÑA', "PARO ALBACETE", 'PARO ALICANTE', 'PARO ALMERIA']#, 'PARO ALAVA', 'PARO ASTURIAS', 'PARO AVILA', 'PARO BADAJOZ', 'PARO BARCELONA', 'PARO BIZKAIA', 'PARO BURGOS', 'PARO CACERES', 'PARO CADIZ', 'PARO CANTABRIA', 'PARO CASTELLON', 'PARO CEUTA', 'PARO CIUDAD REAL', 'PARO CORDOBA', 'PARO CUENCA', 'PARO GIPUZCOA', 'PARO GIRONA', 'PARO GRANADA', 'PARO GUADALAJARA', 'PARO HUELVA', 'PARO HUESCA', 'PARO BALEARES', 'PARO JAEN', 'PARO LA RIOJA', 'PARO LAS PALMAS', 'PARO LEON', 'PARO LLEIDA', 'PARO LUGO', 'PARO MADRID', 'PARO MALAGA', 'PARO MELILLA', 'PARO MURCIA', 'PARO NAVARRA', 'PARO OURENSE', 'PARO PALENCIA', 'PARO PONTEVEDRA', 'PARO SALAMANCA', 'PARO SEGOVIA', 'PARO SEVILLA', 'PARO SORIA', 'PARO STA CRUZ TENER.', 'PARO TARRAGONA', 'PARO TERUEL', 'PARO TOLEDO', 'PARO VALENCIA', 'PARO VALLADOLID', 'PARO ZAMORA', 'PARO ZARAGOZA']

# %%
for provincia in provincias:
    if provincia == 'PARO A CORUÑA':
        aux = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS2010.xls', sheet_name=provincia).iloc[7:,1:3]
    else:
        aux2 = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS2010.xls', sheet_name=provincia).iloc[7:,1:3]
        aux = pd.concat([aux, aux2], axis = 0)
aux.columns = ["Municipio", "2010"]
aux = aux.dropna()
aux
# Out:
#     Municipio   2010
# 7    ABEGONDO    364
# 8        AMES   2348
# 9      ARANGA     97
# 10       ARES    477
# 11    ARTEIXO   2892
# ..        ...    ...
# 54  ZALDUONDO      8
# 55   ZAMBRANA     14
# 56   ZIGOITIA     55
# 57       ZUIA     75
# 58     ALAVA.  20593
#
# [479 rows x 2 columns]

# %%
for provincia in provincias:
    if provincia == 'PARO A CORUÑA':
        aux = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS2011.xls', sheet_name=provincia).iloc[7:,1:3]
    else:
        aux2 = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS2011.xls', sheet_name=provincia).iloc[7:,1:3]
        aux = pd.concat([aux, aux2], axis = 0)
aux.columns = ["Municipio", "2011"]
aux = aux.dropna()
aux
# Out:
#     Municipio   2011
# 7    ABEGONDO    385
# 8        AMES   2646
# 9      ARANGA    101
# 10       ARES    484
# 11    ARTEIXO   3035
# ..        ...    ...
# 54  ZALDUONDO     10
# 55   ZAMBRANA     15
# 56   ZIGOITIA     70
# 57       ZUIA     88
# 58     ALAVA.  21916
#
# [480 rows x 2 columns]

# %%
for provincia in provincias:
    if provincia == 'PARO A CORUÑA':
        aux = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS2012.xls', sheet_name=provincia).iloc[7:,1:3]
    else:
        aux2 = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS2012.xls', sheet_name=provincia).iloc[7:,1:3]
        aux = pd.concat([aux, aux2], axis = 0)
aux.columns = ["Municipio", "2012"]
aux = aux.dropna()
aux
# Out:
#        Municipio   2012
# 7       ABEGONDO    423
# 8           AMES   2964
# 9         ARANGA    122
# 10          ARES    587
# 11       ARTEIXO   3489
# ..           ...    ...
# 54     ZALDUONDO     11
# 55      ZAMBRANA     25
# 56      ZIGOITIA     71
# 57          ZUIA     75
# 58  ARABA/ALAVA.  24217
#
# [480 rows x 2 columns]

# %%
provincias = ['PARO A CORUÑA', "PARO ALBACETE", 'PARO ALICANTE', 'PARO ALMERIA', 'PARO ALAVA']#, 'PARO ASTURIAS', 'PARO AVILA', 'PARO BADAJOZ', 'PARO BARCELONA', 'PARO BIZKAIA', 'PARO BURGOS', 'PARO CACERES', 'PARO CADIZ', 'PARO CANTABRIA', 'PARO CASTELLON', 'PARO CEUTA', 'PARO CIUDAD REAL', 'PARO CORDOBA', 'PARO CUENCA', 'PARO GIPUZCOA', 'PARO GIRONA', 'PARO GRANADA', 'PARO GUADALAJARA', 'PARO HUELVA', 'PARO HUESCA', 'PARO BALEARES', 'PARO JAEN', 'PARO LA RIOJA', 'PARO LAS PALMAS', 'PARO LEON', 'PARO LLEIDA', 'PARO LUGO', 'PARO MADRID', 'PARO MALAGA', 'PARO MELILLA', 'PARO MURCIA', 'PARO NAVARRA', 'PARO OURENSE', 'PARO PALENCIA', 'PARO PONTEVEDRA', 'PARO SALAMANCA', 'PARO SEGOVIA', 'PARO SEVILLA', 'PARO SORIA', 'PARO STA CRUZ TENER.', 'PARO TARRAGONA', 'PARO TERUEL', 'PARO TOLEDO', 'PARO VALENCIA', 'PARO VALLADOLID', 'PARO ZAMORA', 'PARO ZARAGOZA']

paro = pd.DataFrame()  # Inicializa el DataFrame paro

for i in range(2023, 2004, -1):  # Cambiado el rango para incluir 2004
    for provincia in provincias:
        file_path = 'Data_paro/ESTADISTICA_MUNICIPIOS' + str(i) + '.xls'
        if provincia == 'PARO A CORUÑA':
            col_range = "B:C"  # Columnas para A Coruña
            aux = pd.read_excel(file_path, sheet_name=provincia, usecols=col_range, skiprows=7)
        else:
            col_range = "C"  # Columna para otras provincias
            aux2 = pd.read_excel(file_path, sheet_name=provincia, usecols=col_range, skiprows=7)
            aux = pd.concat([aux, aux2], axis = 0)


    if paro.empty:
        paro = aux
    else:
        paro = pd.concat([paro, aux], axis=1)
paro.reset_index(drop=True, inplace=True)


paro
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# c:\Users\Álvaro\Desktop\Bootcamp\Carpeta de trabajo\Proyectos\EDA\Paro.ipynb Cell 7 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/%C3%81lvaro/Desktop/Bootcamp/Carpeta%20de%20trabajo/Proyectos/EDA/Paro.ipynb#X36sZmlsZQ%3D%3D?line=17'>18</a>         paro = aux
#      <a href='vscode-notebook-cell:/c%3A/Users/%C3%81lvaro/Desktop/Bootcamp/Carpeta%20de%20trabajo/Proyectos/EDA/Paro.ipynb#X36sZmlsZQ%3D%3D?line=18'>19</a>     else:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/%C3%81lvaro/Desktop/Bootcamp/Carpeta%20de%20trabajo/Proyectos/EDA/Paro.ipynb#X36sZmlsZQ%3D%3D?line=19'>20</a>         paro = pd.concat([paro, aux], axis=1)
# ...

# %%
#paro.columns = ["Municipio","2023", "2022", "2021", "2020", "2019", "2018", "2017", "2016", "2015", "2014", "2013", "2012", "2011" ]
print(paro)
# Out:
#                      Municipio  2023  2022  2021  2020  2019  2018  2017  \
# 0                     ABEGONDO   199   205   257   214   261   257   294
# 1                         AMES  1571  1707  2059  1897  1913  2067  2206
# 2                       ARANGA    52    58    74    57    51    62    73
# 3                         ARES   302   346   423   377   415   437   500
# 4                      ARTEIXO  1929  1999  2427  2045  2159  2264  2563
# ...                        ...   ...   ...   ...   ...   ...   ...   ...
# 2216                 VILLATOYA     6     8    11    10     9     9    10
# 2217             VILLAVALIENTE    12    14    17    14    15    17    18
# 2218  VILLAVERDE DE GUADALIMAR    41    42    54    55    45    54    51
# 2219                   VIVEROS    17    13    21    27    20    31    29
# 2220                     YESTE   270   277   327   337   248   326   362
#
#       2016  2015  2014  2013  2012  2011  2010
# ...

# %%
provincias = ['PARO A CORUÑA', "PARO ALBACETE"]#, 'PARO ALICANTE', 'PARO ALMERIA', 'PARO ALAVA', 'PARO ASTURIAS', 'PARO AVILA', 'PARO BADAJOZ', 'PARO BARCELONA', 'PARO BIZKAIA']

paro = pd.DataFrame()
aux = pd.DataFrame()

for i in range(2023, 2009, -1):
    for provincia in provincias:
        if provincia == 'PARO A CORUÑA':
            aux = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS'+str(i)+'.xls', sheet_name=provincia).iloc[7:,1:3]
        else:
            aux2 = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS'+str(i)+'.xls', sheet_name=provincia).iloc[7:,1:3]
            aux = pd.concat([aux, aux2], axis = 0)
    aux.columns = ["Municipio", str(i)]
    aux = aux.dropna()
    if i == 2023:
        paro = aux
    #paro.reset_index().iloc[:,1:3]
    else:
        paro = pd.merge(paro, aux)#, on = "Municipio", how = "inner")
    #paro.reset_index(drop=True, inplace=True)
#paro
aux
# Out:
#                    Municipio   2010
# 7                   ABEGONDO    364
# 8                       AMES   2348
# 9                     ARANGA     97
# 10                      ARES    477
# 11                   ARTEIXO   2892
# ..                       ...    ...
# 90             VILLAVALIENTE     21
# 91  VILLAVERDE DE GUADALIMAR     46
# 92                   VIVEROS     30
# 93                     YESTE    443
# 94                 ALBACETE.  40267
#
# [183 rows x 2 columns]

# %%
provincias = ['PARO A CORUÑA', "PARO ALBACETE", 'PARO ALICANTE', 'PARO ALMERIA', 'PARO ALAVA', 'PARO ASTURIAS', 'PARO AVILA', 'PARO BADAJOZ', 'PARO BARCELONA', 'PARO BIZKAIA']

paro = pd.DataFrame()
aux = pd.DataFrame()

for i in range(2023, 2009, -1):
    for provincia in provincias:
        if i ==2023:
            if provincia == 'PARO A CORUÑA':
                aux = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS'+str(i)+'.xls', sheet_name=provincia).iloc[7:,1:3]
            else:
                aux2 = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS'+str(i)+'.xls', sheet_name=provincia).iloc[7:,1:3]
                aux = pd.concat([aux, aux2], axis = 0)
        else:
            if provincia == 'PARO A CORUÑA':
                aux = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS'+str(i)+'.xls', sheet_name=provincia).iloc[7:,1:3]
            else:
                aux2 = pd.read_excel('Data_paro/ESTADISTICA_MUNICIPIOS'+str(i)+'.xls', sheet_name=provincia).iloc[7:,1:3]
                aux = pd.concat([aux, aux2], axis = 0)
    aux.columns = ["Municipio", str(i)]
    aux = aux.dropna()
    if i == 2023:
        paro = pd.concat([paro, aux], axis = 1)
    #paro.reset_index().iloc[:,1:3]
    else:
        paro = pd.merge(paro, aux, on = "Municipio", how = "left")
    #paro.reset_index(drop=True, inplace=True)
#paro
aux
# Out:
#            Municipio   2010
# 7           ABEGONDO    364
# 8               AMES   2348
# 9             ARANGA     97
# 10              ARES    477
# 11           ARTEIXO   2892
# ..               ...    ...
# 115          ZEANURI     35
# 116          ZEBERIO     39
# 117         ZIERBENA     72
# 118  ZIORTZA-BOLIBAR     12
# 119         VIZCAYA.  74180
#
# [1380 rows x 2 columns]

# %%
col = ["CP", "Municipio", "paro2023"]

# %%
paro.columns = col
paro
# Out:
#           CP   Municipio paro2023
# 7     2001.0   ABENGIBRE       26
# 8     2002.0      ALATOZ       39
# 9     2003.0    ALBACETE    11764
# 10    2004.0    ALBATANA       60
# 11    2005.0     ALBOREA       56
# ..       ...         ...      ...
# 296  50295.0  VISTABELLA       <5
# 297  50296.0   ZAIDA, LA       16
# 298  50297.0    ZARAGOZA    33896
# 299  50298.0       ZUERA      315
# 300      NaN    ZARAGOZA    46097
#
# [8186 rows x 3 columns]

# %%
empresas = pd.read_excel('empresas/empresas_municipios.xls').iloc[7:,:]
empresas
# Out:
#                     Resultados municipales    Unnamed: 1 Unnamed: 2  \
# 7                              Total Nacional    3430663    3366570
# 8                              01 Araba/Álava      18771      18628
# 9                      01001 Alegría-Dulantzi        154        169
# 10                              01002 Amurrio        601        596
# 11                              01003 Aramaio         43         46
# ...                                       ...        ...        ...
# 8191              50903 Villamayor de Gállego        155        160
# 8192                                 51 Ceuta       3744       3749
# 8193                              51001 Ceuta       3744       3749
# 8194                               52 Melilla       4856       5024
# 8195                            52001 Melilla       4856       5024
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 7       3404428    3363197    3337646    3282346    3236582    3186878
# ...

# %%
columna_empresas = ["Municipio", "Total2022", "Total2021", "Total2020", "Total2019", "Total2018", "Total2017", "Total2016", "Total2015", "Total2014", "Total2013", "Total2012", "Industria2022", "Industria2021", "Industria2020", "Industria2019", "Industria2018", "Industria2017", "Industria2016", "Industria2015", "Industria2014", "Industria2013", "Industria2012", "Construcción2022", "Construcción2021", "Construcción2020", "Construcción2019", "Construcción2018", "Construcción2017", "Construcción2016", "Construcción2015", "Construcción2014", "Construcción2013", "Construcción2012", "Hostelería2022", "Hostelería2021", "Hostelería2020", "Hostelería2019", "Hostelería2018", "Hostelería2017", "Hostelería2016", "Hostelería2015", "Hostelería2014", "Hostelería2013", "Hostelería2012", "Comunicaciones2022", "Comunicaciones2021", "Comunicaciones2020", "Comunicaciones2019", "Comunicaciones2018", "Comunicaciones2017", "Comunicaciones2016", "Comunicaciones2015", "Comunicaciones2014", "Comunicaciones2013", "Comunicaciones2012", "Finanzas2022", "Finanzas2021", "Finanzas2020", "Finanzas2019", "Finanzas2018", "Finanzas2017", "Finanzas2016", "Finanzas2015", "Finanzas2014", "Finanzas2013", "Finanzas2012", "Inmobiliarias2022", "Inmobiliarias2021", "Inmobiliarias2020", "Inmobiliarias2019", "Inmobiliarias2018", "Inmobiliarias2017", "Inmobiliarias2016", "Inmobiliarias2015", "Inmobiliarias2014", "Inmobiliarias2013", "Inmobiliarias2012", "Tecnicas2022", "Tecnicas2021", "Tecnicas2020", "Tecnicas2019", "Tecnicas2018", "Tecnicas2017", "Tecnicas2016", "Tecnicas2015", "Tecnicas2014", "Tecnicas2013", "Tecnicas2012", "Educacion_Sanidad2022", "Educacion_Sanidad2021", "Educacion_Sanidad2020", "Educacion_Sanidad2019", "Educacion_Sanidad2018", "Educacion_Sanidad2017", "Educacion_Sanidad2016", "Educacion_Sanidad2015", "Educacion_Sanidad2014", "Educacion_Sanidad2013", "Educacion_Sanidad2012", "Otros2022", "Otros2021", "Otros2020", "Otros2019", "Otros2018", "Otros2017", "Otros2016", "Otros2015", "Otros2014", "Otros2013", "Otros2012", "Total_Servicios2022", "Total_Servicios2021", "Total_Servicios2020", "Total_Servicios2019", "Total_Servicios2018", "Total_Servicios2017", "Total_Servicios2016", "Total_Servicios2015", "Total_Servicios2014", "Total_Servicios2013", "Total_Servicios2012"]

# %%
empresas.columns = columna_empresas
empresas
# Out:
#                                     Municipio Total2022 Total2021 Total2020  \
# 7                              Total Nacional   3430663   3366570   3404428
# 8                              01 Araba/Álava     18771     18628     18851
# 9                      01001 Alegría-Dulantzi       154       169       155
# 10                              01002 Amurrio       601       596       601
# 11                              01003 Aramaio        43        46        46
# ...                                       ...       ...       ...       ...
# 8191              50903 Villamayor de Gállego       155       160       160
# 8192                                 51 Ceuta      3744      3749      3845
# 8193                              51001 Ceuta      3744      3749      3845
# 8194                               52 Melilla      4856      5024      5234
# 8195                            52001 Melilla      4856      5024      5234
#
# ...

# %%
csv = pd.read_excel('empresas/empresas_municipios.xls').iloc[6:,:]
csv
# Out:
#                     Resultados municipales    Unnamed: 1 Unnamed: 2  \
# 6                                                   2022       2021
# 7                              Total Nacional    3430663    3366570
# 8                              01 Araba/Álava      18771      18628
# 9                      01001 Alegría-Dulantzi        154        169
# 10                              01002 Amurrio        601        596
# ...                                       ...        ...        ...
# 8191              50903 Villamayor de Gállego        155        160
# 8192                                 51 Ceuta       3744       3749
# 8193                              51001 Ceuta       3744       3749
# 8194                               52 Melilla       4856       5024
# 8195                            52001 Melilla       4856       5024
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 6          2020       2019       2018       2017       2016       2015
# ...

# %%
poblacion2 = pd.read_excel('poblacion/alicante.xls').iloc[6:-9,:]
columna = poblacion2.iloc[0,:]

# %%
#poblacion.columns=poblacion.iloc[0,:]

# %%
prov = ["albacete", "almeria", "alava", "asturias", "avila"]#, "badajoz", "baleares", "barcelona", "vizcaya", "burgos", "caceres"]

# %%
poblacion = pd.read_excel('poblacion/alicante.xls').iloc[7:-9,:]
prov = ["albacete", "almeria", "alava", "asturias", "avila", "badajoz", "baleares", "barcelona", "vizcaya", "burgos", "caceres", "cadiz", "cantabria", "castellon", "ciudad real", "cordoba", "coruna", "cuenca", "guipuzcua", "gerona", "granada", "guadalajara", "huelva", "huesca", "jaen", "leon", "lerida", "lugo", "madrid", "malaga", "murcia", "navarra", "orense", "palencia", "las palmas", "pontevedra", "rioja", "salamanca", "tenerife", "segovia", "sevilla", "soria", "tarragona", "teruel", "toledo", "valencia", "valladolid", "zamora", "zaragoza", "ceuta", "melilla"]
for provin in prov:
    aux = pd.read_excel('poblacion/'+provin+'.xls').iloc[7:-9,:]
    poblacion = pd.concat([poblacion, aux], axis = 0)
poblacion
# Out:
#     Cifras oficiales de población de los municipios españoles en aplicación de la Ley de Bases del Régimen Local (Art. 17)  \
# 7                                  03 Alicante/Alacant
# 8                                          03002 Agost
# 9                                          03003 Agres
# 10                                        03004 Aigües
# 11                                      03005 Albatera
# ..                                                 ...
# 300                                        50298 Zuera
# 7                                             51 Ceuta
# 8                                          51001 Ceuta
# 7                                           52 Melilla
# 8                                        52001 Melilla
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 7      1901594  1881762.0  1879888.0  1858683.0  1838819.0  1825332.0
# 8         4948     4906.0     4794.0     4758.0     4713.0     4703.0
# ...

# %%
poblacion.columns=columna
poblacion
# Out:
# 6                            2022     2021.0     2020.0     2019.0     2018.0  \
# 7    03 Alicante/Alacant  1901594  1881762.0  1879888.0  1858683.0  1838819.0
# 8            03002 Agost     4948     4906.0     4794.0     4758.0     4713.0
# 9            03003 Agres      589      580.0      564.0      565.0      551.0
# 10          03004 Aigües     1085     1049.0      986.0      963.0      936.0
# 11        03005 Albatera    12864    12714.0    12474.0    12279.0    12042.0
# ..                   ...      ...        ...        ...        ...        ...
# 300          50298 Zuera     8632     8591.0     8576.0     8565.0     8365.0
# 7               51 Ceuta    83117    83517.0    84202.0    84777.0    85144.0
# 8            51001 Ceuta    83117    83517.0    84202.0    84777.0    85144.0
# 7             52 Melilla    85170    86261.0    87076.0    86487.0    86384.0
# 8          52001 Melilla    85170    86261.0    87076.0    86487.0    86384.0
#
# ...
